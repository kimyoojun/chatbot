# %%
# auto-encoder example 0-9 digit
# 1 import libraries
from pathlib import PosixPath
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt

import torchvision.datasets as datasets
import torchvision.transforms as transforms

import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 2 prepare dataset
transforms = transforms.Compose([transforms.ToTensor()])

train_dataset = datasets.MNIST(
    root="pytorch/data2", train=True, transform=transforms, download=True
)

test_dataset = datasets.MNIST(
    root="pytorch/data2", train=False, transform=transforms, download=True
)

train_loder = DataLoader(
    train_dataset, batch_size=128, shuffle=True, num_workers=4, pin_memory=False
)

test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)

# %%
# 3 Network Encoder
class Encoder(nn.Module):
    def __init__(self, encoded_space_dim, fc2_input_dim):
        super().__init__()

        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            nn.ReLU(True),
        )

        self.flatten = nn.Flatten(start_dim=1)
        self.encoder_lin = nn.Sequential(
            nn.Linear(3 * 3 * 32, 128), nn.ReLU(True), nn.Linear(128, encoded_space_dim)
        )

    def forward(self, x):
        x = self.encoder_cnn(x)
        x = self.flatten(x)
        x = self.encoder_lin(x)
        return x


class Decoder(nn.Module):
    def __init__(self, decoded_space_dim, fc2_input_dim):
        super().__init__()
        self.decoded_lin = nn.Sequential(
            nn.Linear(decoded_space_dim, 128),
            nn.ReLU(True),
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True),
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))
        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(32, 16, 3, stride=2, padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU6(True),
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1),
        )

    def forward(self, x):
        x = self.decoded_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        return x

# %%
# 4 loss function optimizer
encode = Encoder(encoded_space_dim=4, fc2_input_dim=128).to(device)
decoder = Decoder(decoded_space_dim=4, fc2_input_dim=128).to(device)

params_to_optimize = [
    {"params": encode.parameters()},
    {"params": decoder.parameters()},
]
optim_ob = torch.optim.Adam(params_to_optimize, lr=0.001, weight_decay=1e-05)
loss_fn = torch.nn.MSELoss()

# %%
# 5 add noise
def add_noise(inputs, noise_factor=0.3):
    noisy = inputs + torch.randn_like(inputs) * noise_factor
    noisy = torch.clip(noisy, 0.0, 1.0)
    return noisy

# %%
# 6 train function
def train_epoch(
    encoder, decoder, device, dataloader, loss_fn, optimizer, noise_factor=0.3
):
    encoder.train()
    decoder.train()
    train_loss = []

    for image_batch, _ in dataloader:
        image_noisy = add_noise(image_batch, noise_factor)
        image_noisy = image_noisy.to(device)
        encoded_data = encoder(image_noisy)
        decoded_data = decoder(encoded_data)
        loss = loss_fn(decoded_data, image_noisy)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss.append(loss.detach().cpu().numpy())
    return np.mean(train_loss)

# %%
# 7 test function
def test_epoch(encoder, decoder, device, dataloader, loss_fn, noise_factor=0.3):
    encoder.eval()
    decoder.eval()

    with torch.no_grad():
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            image_noisy = add_noise(image_batch, noise_factor)
            image_noisy = image_noisy.to(device)
            encoded_data = encoder(image_noisy)
            decoded_data = decoder(encoded_data)
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label)
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
# 8 Korean font
from matplotlib import font_manager
import pathlib

temp = pathlib.PosixPath
pathlib.PosixPath = pathlib.WindowsPath
font_fname = pathlib.PosixPath("C:/Windows/Fonts/malgun.ttf")
font_family = font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"] = font_family

# %%
# 9 image visualization
def plot_ae_outputs(encoder, decoder, n=5, noise_factor=0.3):
    plt.figure(figsize=(10, 4.5))
    for i in range(n):
        ax = plt.subplot(3, n, i + 1)
        img = test_dataset[i][0].unsqueeze(0)
        image_noisy = add_noise(img, noise_factor)
        image_noisy = image_noisy.to(device)

        encoder.eval()
        decoder.eval()
        with torch.no_grad():
            rec_img = decoder(encoder(image_noisy))

        plt.imshow(img.cpu().squeeze().numpy(), cmap="gray")
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n // 2:
            ax.set_title("original image")
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(image_noisy.cpu().squeeze().numpy(), cmap="gray")
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n // 2:
            ax.set_title("noisy image")
        ax = plt.subplot(3, n, i + 1 + n + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap="gray")
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n // 2:
            ax.set_title("reconstructed image")
    plt.subplots_adjust(
        left=0.1, bottom=0.1, right=0.7, top=0.9, wspace=0.3, hspace=0.3
    )
    plt.show()

# %%
# 10 model train
import numpy as np

num_epochs = 30
history_da = {"train_loss": [], "test_loss": []}
loss_fn = torch.nn.MSELoss()

for epoch in range(num_epochs):
    print(f"Epoch {epoch+1}/{num_epochs}")
    train_loss = train_epoch(
        encode, decoder, device, train_loder, loss_fn, optim_ob, noise_factor=0.3
    )
    val_loss = test_epoch(
        encode, decoder, device, test_loader, loss_fn, noise_factor=0.3
    )
    history_da["train_loss"].append(train_loss)
    history_da["test_loss"].append(val_loss)
    print(
        f"\n Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.3f}, Test Loss: {val_loss:.3f}"
    )
    plot_ae_outputs(encode, decoder, noise_factor=0.3)
# Out:
# Epoch 1/30
#
#  Epoch 1/30, Train Loss: 0.077, Test Loss: 0.054
# Epoch 2/30
#
#  Epoch 2/30, Train Loss: 0.057, Test Loss: 0.048
# Epoch 3/30
#
#  Epoch 3/30, Train Loss: 0.054, Test Loss: 0.044
# Epoch 4/30
#
#  Epoch 4/30, Train Loss: 0.053, Test Loss: 0.042
# Epoch 5/30
#
#  Epoch 5/30, Train Loss: 0.052, Test Loss: 0.041
# Epoch 6/30
#
#  Epoch 6/30, Train Loss: 0.051, Test Loss: 0.041
# Epoch 7/30
#
#  Epoch 7/30, Train Loss: 0.051, Test Loss: 0.040
# Epoch 8/30
#
#  Epoch 8/30, Train Loss: 0.051, Test Loss: 0.040
# Epoch 9/30
#
#  Epoch 9/30, Train Loss: 0.051, Test Loss: 0.040
# Epoch 10/30
#
#  Epoch 10/30, Train Loss: 0.050, Test Loss: 0.039
# Epoch 11/30
#
#  Epoch 11/30, Train Loss: 0.050, Test Loss: 0.039
# Epoch 12/30
#
#  Epoch 12/30, Train Loss: 0.050, Test Loss: 0.039
# Epoch 13/30
#
#  Epoch 13/30, Train Loss: 0.050, Test Loss: 0.039
# Epoch 14/30
#
#  Epoch 14/30, Train Loss: 0.050, Test Loss: 0.038
# Epoch 15/30
#
#  Epoch 15/30, Train Loss: 0.050, Test Loss: 0.039
# Epoch 16/30
#
#  Epoch 16/30, Train Loss: 0.050, Test Loss: 0.039
# Epoch 17/30
#
#  Epoch 17/30, Train Loss: 0.050, Test Loss: 0.039
# Epoch 18/30
#
#  Epoch 18/30, Train Loss: 0.050, Test Loss: 0.038
# Epoch 19/30
#
#  Epoch 19/30, Train Loss: 0.050, Test Loss: 0.038
# Epoch 20/30
#
#  Epoch 20/30, Train Loss: 0.050, Test Loss: 0.038
# Epoch 21/30
#
#  Epoch 21/30, Train Loss: 0.050, Test Loss: 0.038
# Epoch 22/30
#
#  Epoch 22/30, Train Loss: 0.049, Test Loss: 0.038
# Epoch 23/30
#
#  Epoch 23/30, Train Loss: 0.049, Test Loss: 0.038
# Epoch 24/30
#
#  Epoch 24/30, Train Loss: 0.049, Test Loss: 0.038
# Epoch 25/30
#
#  Epoch 25/30, Train Loss: 0.049, Test Loss: 0.038
# Epoch 26/30
#
#  Epoch 26/30, Train Loss: 0.049, Test Loss: 0.038
# Epoch 27/30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\chatbot\python\pytorch\torch46.ipynb Cell 10 line 1
#       <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a> for epoch in range(num_epochs):
#       <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a>     print(f"Epoch {epoch+1}/{num_epochs}")
# ---> <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a>     train_loss = train_epoch(
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a>         encode, decoder, device, train_loder, loss_fn, optim_ob, noise_factor=0.3
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a>     )
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a>     val_loss = test_epoch(
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a>         encode, decoder, device, test_loader, loss_fn, noise_factor=0.3
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a>     )
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a>     history_da["train_loss"].append(train_loss)
#
# c:\chatbot\python\pytorch\torch46.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a>     optimizer.zero_grad()
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a>     loss.backward()
# ---> <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a>     optimizer.step()
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a>     train_loss.append(loss.detach().cpu().numpy())
#      <a href='vscode-notebook-cell:/c%3A/chatbot/python/pytorch/torch46.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> return np.mean(train_loss)
#
# File c:\Users\admin\anaconda3\Lib\site-packages\torch\optim\optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File c:\Users\admin\anaconda3\Lib\site-packages\torch\optim\optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File c:\Users\admin\anaconda3\Lib\site-packages\torch\optim\adam.py:141, in Adam.step(self, closure)
#     130     beta1, beta2 = group['betas']
#     132     self._init_group(
#     133         group,
#     134         params_with_grad,
#    (...)
#     138         max_exp_avg_sqs,
#     139         state_steps)
# --> 141     adam(
#     142         params_with_grad,
#     143         grads,
#     144         exp_avgs,
#     145         exp_avg_sqs,
#     146         max_exp_avg_sqs,
#     147         state_steps,
#     148         amsgrad=group['amsgrad'],
#     149         beta1=beta1,
#     150         beta2=beta2,
#     151         lr=group['lr'],
#     152         weight_decay=group['weight_decay'],
#     153         eps=group['eps'],
#     154         maximize=group['maximize'],
#     155         foreach=group['foreach'],
#     156         capturable=group['capturable'],
#     157         differentiable=group['differentiable'],
#     158         fused=group['fused'],
#     159         grad_scale=getattr(self, "grad_scale", None),
#     160         found_inf=getattr(self, "found_inf", None),
#     161     )
#     163 return loss
#
# File c:\Users\admin\anaconda3\Lib\site-packages\torch\optim\adam.py:281, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     278 else:
#     279     func = _single_tensor_adam
# --> 281 func(params,
#     282      grads,
#     283      exp_avgs,
#     284      exp_avg_sqs,
#     285      max_exp_avg_sqs,
#     286      state_steps,
#     287      amsgrad=amsgrad,
#     288      beta1=beta1,
#     289      beta2=beta2,
#     290      lr=lr,
#     291      weight_decay=weight_decay,
#     292      eps=eps,
#     293      maximize=maximize,
#     294      capturable=capturable,
#     295      differentiable=differentiable,
#     296      grad_scale=grad_scale,
#     297      found_inf=found_inf)
#
# File c:\Users\admin\anaconda3\Lib\site-packages\torch\optim\adam.py:335, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     332 step_t += 1
#     334 if weight_decay != 0:
# --> 335     grad = grad.add(param, alpha=weight_decay)
#     337 if torch.is_complex(param):
#     338     grad = torch.view_as_real(grad)
#
# KeyboardInterrupt:
